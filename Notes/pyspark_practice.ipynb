# %% [markdown]
# ### Pyspark Practice

# %%
# %sql
SELECT * FROM adventure_works_customers;

# %% [markdown]
# What is dataframe? how to create dataframe? how to read dataframe? how to see schema of dataframe?

# %%
# A DataFrame is a distributed collection of data organized into named columns.

# Create a DataFrame from a list of tuples
data = [("Alice", 34), ("Bob", 45)]
columns = ["Name", "Age"]
df = spark.createDataFrame(data, columns)

# Read a DataFrame from a CSV file
df_csv = spark.read.csv("/databricks-datasets/airlines/part-00000", header=True, inferSchema=True)

# See the schema of a DataFrame
df.printSchema()
df_csv.printSchema()

# Display the DataFrame
display(df)
display(df_csv)

# %%
df = spark.sql("SELECT * FROM adventure_works_customers")
df = df.limit(10)

display(df)

# %%
df=spark.read.format("csv").option("header", "true").option("inferSchema", "true").load("/databricks-datasets/learning-spark-v2/people/people-10m.delta")
display(df)

# %%
df3=spark.read.format("delta").option("header", "true").option("inferSchema", "true").load("/databricks-datasets/learning-spark-v2/people/people-10m.delta")
display(df3)
df4=spark.read.format("delta")
display(df4)
